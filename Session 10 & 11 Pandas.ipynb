# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Titanic.csv')

# %%
df.size
# Out:
# 18326

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
df.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
# gives values of integers and floats and not strings
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
# includes all values including string and all other datatypes
df.describe(include='all')
# Out:
#              pclass     survived                  name   sex          age  \
# count   1309.000000  1309.000000                  1309  1309  1046.000000
# unique          NaN          NaN                  1307     2          NaN
# top             NaN          NaN  Connolly, Miss. Kate  male          NaN
# freq            NaN          NaN                     2   843          NaN
# mean       2.294882     0.381971                   NaN   NaN    29.881138
# std        0.837836     0.486055                   NaN   NaN    14.413493
# min        1.000000     0.000000                   NaN   NaN     0.170000
# 25%        2.000000     0.000000                   NaN   NaN    21.000000
# 50%        3.000000     0.000000                   NaN   NaN    28.000000
# 75%        3.000000     1.000000                   NaN   NaN    39.000000
# max        3.000000     1.000000                   NaN   NaN    80.000000
#
#               sibsp        parch    ticket         fare        cabin embarked  \
# ...

# %%
# display the columns in the dataframe
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df.shape
# Out:
# (1309, 14)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1309, step=1)

# %%
# returns the column in series
gender = df['sex']
type(gender)
# Out:
# pandas.core.series.Series

# %%
# returns the column in dataframe
temp = df[['sex']]
type(temp)
# Out:
# pandas.core.frame.DataFrame

# %%
# returns the column in dataframe
temp = df[['sex', 'age']]
type(temp)
# Out:
# pandas.core.frame.DataFrame

# %%
temp.shape
# Out:
# (1309, 2)

# %%
gender.shape
# Out:
# (1309,)

# %%
# gives number/count of values in a column
temp.value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
# gives name of unique columns
gender.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# gives name of unique columns
temp['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# gives number of unique values in the column
temp['sex'].nunique()
# Out:
# 2

# %%
df['home.dest'].isna().value_counts()
# Out:
# home.dest
# False    745
# True     564
# Name: count, dtype: int64

# %%
df.isna()
# Out:
#       pclass  survived   name    sex    age  sibsp  parch  ticket   fare  \
# 0      False     False  False  False  False  False  False   False  False
# 1      False     False  False  False  False  False  False   False  False
# 2      False     False  False  False  False  False  False   False  False
# 3      False     False  False  False  False  False  False   False  False
# 4      False     False  False  False  False  False  False   False  False
# ...      ...       ...    ...    ...    ...    ...    ...     ...    ...
# 1304   False     False  False  False  False  False  False   False  False
# 1305   False     False  False  False   True  False  False   False  False
# 1306   False     False  False  False  False  False  False   False  False
# 1307   False     False  False  False  False  False  False   False  False
# 1308   False     False  False  False  False  False  False   False  False
#
#       cabin  embarked   boat   body  home.dest
# ...

# %%
df.isnull()
# Out:
#       pclass  survived   name    sex    age  sibsp  parch  ticket   fare  \
# 0      False     False  False  False  False  False  False   False  False
# 1      False     False  False  False  False  False  False   False  False
# 2      False     False  False  False  False  False  False   False  False
# 3      False     False  False  False  False  False  False   False  False
# 4      False     False  False  False  False  False  False   False  False
# ...      ...       ...    ...    ...    ...    ...    ...     ...    ...
# 1304   False     False  False  False  False  False  False   False  False
# 1305   False     False  False  False   True  False  False   False  False
# 1306   False     False  False  False  False  False  False   False  False
# 1307   False     False  False  False  False  False  False   False  False
# 1308   False     False  False  False  False  False  False   False  False
#
#       cabin  embarked   boat   body  home.dest
# ...

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
df.values
# Out:
# array([[1, 1, 'Allen, Miss. Elisabeth Walton', ..., '2', nan,
#         'St Louis, MO'],
#        [1, 1, 'Allison, Master. Hudson Trevor', ..., '11', nan,
#         'Montreal, PQ / Chesterville, ON'],
#        [1, 0, 'Allison, Miss. Helen Loraine', ..., nan, nan,
#         'Montreal, PQ / Chesterville, ON'],
#        ...,
#        [3, 0, 'Zakarian, Mr. Mapriededer', ..., nan, 304.0, nan],
#        [3, 0, 'Zakarian, Mr. Ortin', ..., nan, nan, nan],
#        [3, 0, 'Zimmerman, Mr. Leo', ..., nan, nan, nan]], dtype=object)

# %%
type(df.values)
# Out:
# numpy.ndarray

# %%
df['age'].values
# Out:
# array([29.  ,  0.92,  2.  , ..., 26.5 , 27.  , 29.  ])

# %%
type(df['age'].values)
# Out:
# numpy.ndarray

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
arr_subset = df[['sex', 'age', 'cabin']]
arr_subset
# Out:
#          sex    age    cabin
# 0     female  29.00       B5
# 1       male   0.92  C22 C26
# 2     female   2.00  C22 C26
# 3       male  30.00  C22 C26
# 4     female  25.00  C22 C26
# ...      ...    ...      ...
# 1304  female  14.50      NaN
# 1305  female    NaN      NaN
# 1306    male  26.50      NaN
# 1307    male  27.00      NaN
# 1308    male  29.00      NaN
#
# [1309 rows x 3 columns]

# %%
type(arr_subset)
# Out:
# pandas.core.frame.DataFrame

# %%
arr_subset.head()
# Out:
#       sex    age    cabin
# 0  female  29.00       B5
# 1    male   0.92  C22 C26
# 2  female   2.00  C22 C26
# 3    male  30.00  C22 C26
# 4  female  25.00  C22 C26

# %%
arr_subset.tail(10)
# Out:
#          sex   age cabin
# 1299    male  27.0   NaN
# 1300  female  15.0   NaN
# 1301    male  45.5   NaN
# 1302    male   NaN   NaN
# 1303    male   NaN   NaN
# 1304  female  14.5   NaN
# 1305  female   NaN   NaN
# 1306    male  26.5   NaN
# 1307    male  27.0   NaN
# 1308    male  29.0   NaN

# %%
arr_subset.tail()
# Out:
#          sex   age cabin
# 1304  female  14.5   NaN
# 1305  female   NaN   NaN
# 1306    male  26.5   NaN
# 1307    male  27.0   NaN
# 1308    male  29.0   NaN

# %%
df_filter = df[df['age'] > 20]
df_filter
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# ...      ...       ...                                              ...
# 1299       3         0                              Yasbeck, Mr. Antoni
# 1301       3         0                             Youseff, Mr. Gerious
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df_filter.describe()
# Out:
#            pclass    survived         age       sibsp       parch        fare  \
# count  798.000000  798.000000  798.000000  798.000000  798.000000  797.000000
# mean     2.095238    0.392231   35.194862    0.350877    0.319549   39.069902
# std      0.856565    0.488554   11.799318    0.592460    0.822759   59.629825
# min      1.000000    0.000000   20.500000    0.000000    0.000000    0.000000
# 25%      1.000000    0.000000   26.000000    0.000000    0.000000    8.050000
# 50%      2.000000    0.000000   32.000000    0.000000    0.000000   15.850000
# 75%      3.000000    1.000000   42.000000    1.000000    0.000000   39.687500
# max      3.000000    1.000000   80.000000    4.000000    6.000000  512.329200
#
#              body
# count  106.000000
# mean   162.547170
# std     94.414601
# min      7.000000
# 25%     79.250000
# 50%    160.500000
# 75%    253.500000
# max    327.000000

# %%
# sorts the rows based on the column
df_sort = df.sort_values(by= 'age', ascending=False)
df_sort
# Out:
#       pclass  survived                                               name  \
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 1235       3         0                                Svensson, Mr. Johan
# 9          1         0                            Artagaveytia, Mr. Ramon
# 135        1         0                          Goldschmidt, Mr. George B
# ...      ...       ...                                                ...
# 1293       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1305       3         0                              Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch      ticket     fare cabin embarked boat  \
# ...

# %%
df
# Out:
#       pclass  survived                                               name  \
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 1235       3         0                                Svensson, Mr. Johan
# 9          1         0                            Artagaveytia, Mr. Ramon
# 135        1         0                          Goldschmidt, Mr. George B
# ...      ...       ...                                                ...
# 1293       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1305       3         0                              Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch      ticket     fare cabin embarked boat  \
# ...

# %%
# sorts the rows based on the column and changes the original dataframe(inplace is used)
df.sort_values(by = 'age', inplace = True, ascending = False)

# %%
df
# Out:
#       pclass  survived                                               name  \
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 1235       3         0                                Svensson, Mr. Johan
# 9          1         0                            Artagaveytia, Mr. Ramon
# 135        1         0                          Goldschmidt, Mr. George B
# ...      ...       ...                                                ...
# 1293       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1305       3         0                              Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch      ticket     fare cabin embarked boat  \
# ...

# %%
df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['survived'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['survived'].nunique()
# Out:
# 2

# %%
df['survived'].value_counts()
# Out:
# survived
# 0    809
# 1    500
# Name: count, dtype: int64

# %%
df_survived = df[df['survived'] == 1]
df_survived['survived'].value_counts()
# Out:
# survived
# 1    500
# Name: count, dtype: int64

# %%
df_survived.shape
# Out:
# (500, 14)

# %%
df_deceased = df[df['survived'] == 0]

# %%
df_deceased['survived'].value_counts()
# Out:
# survived
# 0    809
# Name: count, dtype: int64

# %%
df_deceased.shape
# Out:
# (809, 14)

# %%
df_survived_female = df[(df['sex'] == 'female') & (df['survived'] == 1)]

# %%
df_survived_female
# Out:
#       pclass  survived                                               name  \
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 83         1         1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 78         1         1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 1261       3         1                             Turkula, Mrs. (Hedwig)
# ...      ...       ...                                                ...
# 1149       3         1                    Riordan, Miss. Johanna "Hannah"
# 1159       3         1                                Roth, Miss. Sarah A
# 1198       3         1                         Shine, Miss. Ellen Natalia
# 1216       3         1                                 Smyth, Miss. Julia
# 1247       3         1  Thorneycroft, Mrs. Percival (Florence Kate White)
#
#          sex   age  sibsp  parch    ticket     fare cabin embarked boat  body  \
# ...

# %%
df_survived_female.shape
# Out:
# (339, 14)

# %%
# Groups based on the column
no_of_gender = df.groupby('sex')
type(no_of_gender)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
no_of_gender.size()
# Out:
# sex
# female    466
# male      843
# dtype: int64

# %%
deceased_gender = df_deceased.groupby('sex').size()

# %%
deceased_gender
# Out:
# sex
# female    127
# male      682
# dtype: int64

# %%
deceased_gender = df_deceased.groupby('sex').value_counts()

# %%
deceased_gender
# Out:
# Series([], Name: count, dtype: int64)

# %%
survived_gender = df_survived.groupby('sex').size()
survived_gender
# Out:
# sex
# female    339
# male      161
# dtype: int64

# %%
test1 = df.groupby(['sex', 'age']).size()
test1
# Out:
# sex     age
# female  0.17     1
#         0.75     2
#         0.92     1
#         1.00     5
#         2.00     7
#                 ..
# male    70.00    2
#         70.50    1
#         71.00    2
#         74.00    1
#         80.00    1
# Length: 166, dtype: int64

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
class_1 = df.groupby('sex').size()
class_1
# Out:
# sex
# female    466
# male      843
# dtype: int64

# %%
survived = df[df['survived'] == 1]
survived.shape
# Out:
# (500, 14)

# %%
class_1_survived = survived[survived['pclass'] == 1]

# %%
class_1_survived.shape
# Out:
# (200, 14)

# %%
class_2_survived = survived[survived['pclass'] == 2]

# %%
class_2_survived.shape
# Out:
# (119, 14)

# %%
class_3_survived = survived[survived['pclass'] == 3]

# %%
class_3_survived.shape
# Out:
# (181, 14)

# %%
class_1 = df[df['pclass'] == 1]
class_1.shape
# Out:
# (323, 14)

# %%
class_2 = df[df['pclass'] == 2]
class_2.shape
# Out:
# (277, 14)

# %%
class_3 = df[df['pclass'] == 3]
class_3.shape
# Out:
# (709, 14)

# %%
passenger_class_count = df['pclass'].value_counts().sort_index()
passenger_class_count
# Out:
# pclass
# 1    323
# 2    277
# 3    709
# Name: count, dtype: int64

# %%
# gives the count of the pclass of the people who survived
survived_count_by_class = df.groupby('pclass')['survived'].sum()
survived_count_by_class
# Out:
# pclass
# 1    200
# 2    119
# 3    181
# Name: survived, dtype: int64

# %%
# creates a dataframe of the columns mentioned
pclass_summary = pd.DataFrame({'Total_Passengers': passenger_class_count, 'Survived': survived_count_by_class}).sort_index()
pclass_summary
# Out:
#         Total_Passengers  Survived
# pclass
# 1                    323       200
# 2                    277       119
# 3                    709       181

# %%
pclass_summary['Deceased'] = pclass_summary['Total_Passengers'] - pclass_summary['Survived']
pclass_summary
# Out:
#         Total_Passengers  Survived  Deceased
# pclass
# 1                    323       200       123
# 2                    277       119       158
# 3                    709       181       528

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
mean_fare = df['fare'].mean()
mean_fare
# Out:
# 33.29547928134557

# %%
mean_fare_by_class = df.groupby('pclass')['fare'].mean()
mean_fare_by_class
# Out:
# pclass
# 1    87.508992
# 2    21.179196
# 3    13.302889
# Name: fare, dtype: float64

# %%
max_fare_by_class = df.groupby('pclass')['fare'].max()
max_fare_by_class
# Out:
# pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: fare, dtype: float64

# %%
min_fare_by_class = df.groupby('pclass')['fare'].min()
min_fare_by_class
# Out:
# pclass
# 1    0.0
# 2    0.0
# 3    0.0
# Name: fare, dtype: float64

# %%
fare_by_class = pd.DataFrame({'Min_Fare': min_fare_by_class, 'Max_Fare': max_fare_by_class, 'Average_Fare': mean_fare_by_class}).sort_index()
fare_by_class
# Out:
#         Min_Fare  Max_Fare  Average_Fare
# pclass
# 1            0.0  512.3292     87.508992
# 2            0.0   73.5000     21.179196
# 3            0.0   69.5500     13.302889

# %%
gender_mean_age = df.groupby('sex')['age'].mean()

# %%
gender_mean_age
# Out:
# sex
# female    28.687088
# male      30.585228
# Name: age, dtype: float64

# %%
# Group by 'pclass' and 'sex' and the find the mean age
gender_mean_age_by_class = df.groupby(['pclass', 'sex'])['age'].mean()
gender_mean_age_by_class
# Out:
# pclass  sex
# 1       female    37.037594
#         male      41.029272
# 2       female    27.499223
#         male      30.815380
# 3       female    22.185329
#         male      25.962264
# Name: age, dtype: float64

# %% [markdown]
# ## Session 11

# %%
# Adds a column to the dataframe using two existing columns
df['family_size'] = df['sibsp'] + df['parch']
print(df[['family_size', 'sibsp','parch']])
# Out:
#       family_size  sibsp  parch
# 0               0      0      0
# 1               3      1      2
# 2               3      1      2
# 3               3      1      2
# 4               3      1      2
# ...           ...    ...    ...
# 1304            1      1      0
# 1305            1      1      0
# 1306            0      0      0
# 1307            0      0      0
# 1308            0      0      0
#
# [1309 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest',
#        'family_size'],
#       dtype='object')

# %%
df.drop(['family_size'], axis = 1, inplace=True)

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
missing_percentage = df.isnull().mean()*100
missing_percentage
# Out:
# pclass        0.000000
# survived      0.000000
# name          0.000000
# sex           0.000000
# age          20.091673
# sibsp         0.000000
# parch         0.000000
# ticket        0.000000
# fare          0.076394
# cabin        77.463713
# embarked      0.152788
# boat         62.872422
# body         90.756303
# home.dest    43.086325
# dtype: float64

# %%
percentage = df.notnull().mean()*100
percentage
# Out:
# pclass       100.000000
# survived     100.000000
# name         100.000000
# sex          100.000000
# age           79.908327
# sibsp        100.000000
# parch        100.000000
# ticket       100.000000
# fare          99.923606
# cabin         22.536287
# embarked      99.847212
# boat          37.127578
# body           9.243697
# home.dest     56.913675
# dtype: float64

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %% [markdown]
# ## df.iloc

# %%
df.loc[0:10]
# Out:
#     pclass  survived                                             name     sex  \
# 0        1         1                    Allen, Miss. Elisabeth Walton  female
# 1        1         1                   Allison, Master. Hudson Trevor    male
# 2        1         0                     Allison, Miss. Helen Loraine  female
# 3        1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4        1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5        1         1                              Anderson, Mr. Harry    male
# 6        1         1                Andrews, Miss. Kornelia Theodosia  female
# 7        1         0                           Andrews, Mr. Thomas Jr    male
# 8        1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9        1         0                          Artagaveytia, Mr. Ramon    male
# 10       1         0                           Astor, Col. John Jacob    male
#
# ...

# %%
df.loc[10:20,['name', 'age', 'sex', 'fare']]
# Out:
#                                                  name   age     sex      fare
# 10                             Astor, Col. John Jacob  47.0    male  227.5250
# 11  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  18.0  female  227.5250
# 12                      Aubart, Mme. Leontine Pauline  24.0  female   69.3000
# 13                       Barber, Miss. Ellen "Nellie"  26.0  female   78.8500
# 14               Barkworth, Mr. Algernon Henry Wilson  80.0    male   30.0000
# 15                                Baumann, Mr. John D   NaN    male   25.9250
# 16                           Baxter, Mr. Quigg Edmond  24.0    male  247.5208
# 17    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  50.0  female  247.5208
# 18                              Bazzani, Miss. Albina  32.0  female   76.2917
# 19                               Beattie, Mr. Thomson  36.0    male   75.2417
# 20                      Beckwith, Mr. Richard Leonard  37.0    male   52.5542

# %%
df.shape
# Out:
# (1309, 14)

# %%
# Filtering out columns using loc instance
df_cleaned = df.loc[:, df.isnull().mean() < 0.7]
print(df_cleaned.shape)
print(df_cleaned.columns)
# Out:
# (1309, 12)
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'embarked', 'boat', 'home.dest'],
#       dtype='object')

# %%
missing_percentage = df_cleaned.isnull().mean()*100
missing_percentage
# Out:
# pclass        0.000000
# survived      0.000000
# name          0.000000
# sex           0.000000
# age          20.091673
# sibsp         0.000000
# parch         0.000000
# ticket        0.000000
# fare          0.076394
# embarked      0.152788
# boat         62.872422
# home.dest    43.086325
# dtype: float64

# %%
# Filtering out columns using loc instance
df_cleaned = df.loc[:, df.isnull().mean() < 0.25]
print(df_cleaned.shape)
print(df_cleaned.columns)
# Out:
# (1309, 10)
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'embarked'],
#       dtype='object')

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   survived  1309 non-null   int64
#  2   name      1309 non-null   object
#  3   sex       1309 non-null   object
#  4   age       1046 non-null   float64
#  5   sibsp     1309 non-null   int64
#  6   parch     1309 non-null   int64
#  7   ticket    1309 non-null   object
#  8   fare      1308 non-null   float64
#  9   embarked  1307 non-null   object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 102.4+ KB

# %%
# drops the rows which has a null value
df_cleaned = df_cleaned.dropna()

# %%
df_cleaned.shape
# Out:
# (1043, 10)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1043 entries, 0 to 1308
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1043 non-null   int64
#  1   survived  1043 non-null   int64
#  2   name      1043 non-null   object
#  3   sex       1043 non-null   object
#  4   age       1043 non-null   float64
#  5   sibsp     1043 non-null   int64
#  6   parch     1043 non-null   int64
#  7   ticket    1043 non-null   object
#  8   fare      1043 non-null   float64
#  9   embarked  1043 non-null   object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 89.6+ KB

# %%
# drops the columns which has null values(axis = 1 means columns and axis = 0 means rows)
df_cleaned.dropna(axis=1)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1301       3         0                             Youseff, Mr. Gerious
# 1304       3         0                             Zabour, Miss. Hileni
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare embarked
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1043 entries, 0 to 1308
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1043 non-null   int64
#  1   survived  1043 non-null   int64
#  2   name      1043 non-null   object
#  3   sex       1043 non-null   object
#  4   age       1043 non-null   float64
#  5   sibsp     1043 non-null   int64
#  6   parch     1043 non-null   int64
#  7   ticket    1043 non-null   object
#  8   fare      1043 non-null   float64
#  9   embarked  1043 non-null   object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 89.6+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
# Filling null values in a column
df['body'] = df['body'].fillna(0)

df['age'] = df['age'].fillna(df['age'].mean())

df['fare'] = df['fare'].fillna(df['fare'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       1309 non-null   float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex        age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %%
df['cabin'] = df['cabin'].fillna('unknown')

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex        age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %%
df['boat'].nunique()
# Out:
# 27

# %%
df['boat'].unique()
# Out:
# array(['2', '11', nan, '3', '10', 'D', '4', '9', '6', 'B', '8', 'A', '5',
#        '7', 'C', '14', '5 9', '13', '1', '15', '5 7', '8 10', '12', '16',
#        '13 15 B', 'C D', '15 16', '13 15'], dtype=object)

# %%
df['boat'] = df['boat'].fillna('unknown')

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex        age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   float64
#  9   cabin      1309 non-null   object
#  10  embarked   1307 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df['home.dest'] = df['home.dest'].fillna('unknown')

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex        age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   float64
#  9   cabin      1309 non-null   object
#  10  embarked   1307 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   float64
#  13  home.dest  1309 non-null   object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df['embarked'] = df['embarked'].fillna('unknown')

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex        age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   float64
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   float64
#  13  home.dest  1309 non-null   object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB
