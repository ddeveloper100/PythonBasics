# %%
import pandas as pd

# %% [markdown]
# #### 1. Load Dataset:
# #### o Load the Airbnb Listings dataset using Pandas. How many rows and columns does the dataset have?

# %%
df = pd.read_csv('./Dataset/listings.csv')

# %%
print(f'The number of rows and columns are: {df.shape}')
# Out:
# The number of rows and columns are: (3818, 92)

# %% [markdown]
# #### 2. Basic Information:
# #### o Display the first 5 rows of the dataset

# %%
df.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %% [markdown]
# #### 3. Column Names:
# #### o List all column names from the dataset.

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
# ...

# %% [markdown]
# #### 4. Data Types:
# #### o Check the data types of all the columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
# ...

# %% [markdown]
# #### Handling Missing Values:
# #### o Count the total number of missing values in the dataset.

# %%
df.isnull().sum()
# Out:
# id                                    0
# listing_url                           0
# scrape_id                             0
# last_scraped                          0
# name                                  0
#                                    ...
# cancellation_policy                   0
# require_guest_profile_picture         0
# require_guest_phone_verification      0
# calculated_host_listings_count        0
# reviews_per_month                   627
# Length: 92, dtype: int64

# %% [markdown]
# #### 6. Drop Columns:
# #### o Drop any irrelevant columns like 'id' or 'host_id' and display the new dataframe

# %%
df.drop(['id'], axis = 1, inplace = True)

# %%
df
# Out:
#                                 listing_url       scrape_id last_scraped  \
# 0       https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1       https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2      https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3      https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4       https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
# ...                                     ...             ...          ...
# 3813   https://www.airbnb.com/rooms/8101950  20160104002432   2016-01-04
# 3814   https://www.airbnb.com/rooms/8902327  20160104002432   2016-01-04
# 3815  https://www.airbnb.com/rooms/10267360  20160104002432   2016-01-04
# 3816   https://www.airbnb.com/rooms/9604740  20160104002432   2016-01-04
# 3817  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
#
#                                      name  \
# 0            Stylish Queen Anne Apartment
# ...

# %%
df.shape
# Out:
# (3818, 91)

# %% [markdown]
# #### Basic Summary Statistics:
# #### o Show the summary statistics for all numerical columns.

# %%
df.describe()
# Out:
#           scrape_id       host_id  host_listings_count  \
# count  3.818000e+03  3.818000e+03          3816.000000
# mean   2.016010e+13  1.578556e+07             7.157757
# std    0.000000e+00  1.458382e+07            28.628149
# min    2.016010e+13  4.193000e+03             1.000000
# 25%    2.016010e+13  3.275204e+06             1.000000
# 50%    2.016010e+13  1.055814e+07             1.000000
# 75%    2.016010e+13  2.590309e+07             3.000000
# max    2.016010e+13  5.320861e+07           502.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                3816.000000  3818.000000  3818.000000   3818.000000
# mean                    7.157757    47.628961  -122.333103      3.349398
# std                    28.628149     0.043052     0.031745      1.977599
# min                     1.000000    47.505088  -122.417219      1.000000
# 25%                     1.000000    47.609418  -122.354320      2.000000
# ...

# %% [markdown]
# #### Filtering Data:
# #### o Filter the data to show listings where the price is greater than $100.

# %%
df[['price']]
# Out:
#         price
# 0      $85.00
# 1     $150.00
# 2     $975.00
# 3     $100.00
# 4     $450.00
# ...       ...
# 3813  $359.00
# 3814   $79.00
# 3815   $93.00
# 3816   $99.00
# 3817   $87.00
#
# [3818 rows x 1 columns]

# %%
df['price'] = df['price'].str.replace('$','')
df['price']
# Out:
# 0        85.00
# 1       150.00
# 2       975.00
# 3       100.00
# 4       450.00
#          ...
# 3813    359.00
# 3814     79.00
# 3815     93.00
# 3816     99.00
# 3817     87.00
# Name: price, Length: 3818, dtype: object

# %%
df['price'] = df['price'].str.replace(',','')
df['price']
# Out:
# 0        85.00
# 1       150.00
# 2       975.00
# 3       100.00
# 4       450.00
#          ...
# 3813    359.00
# 3814     79.00
# 3815     93.00
# 3816     99.00
# 3817     87.00
# Name: price, Length: 3818, dtype: object

# %%
# df['price'] = df['price'].astype(float)
df['price'] = pd.to_numeric(df['price'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
# ...

# %%
df_filter = df[df['price'] > 100]
df_filter
# Out:
#            id                           listing_url       scrape_id  \
# 1      953595   https://www.airbnb.com/rooms/953595  20160104002432
# 2     3308979  https://www.airbnb.com/rooms/3308979  20160104002432
# 4      278830   https://www.airbnb.com/rooms/278830  20160104002432
# 5     5956968  https://www.airbnb.com/rooms/5956968  20160104002432
# 9     2493658  https://www.airbnb.com/rooms/2493658  20160104002432
# ...       ...                                   ...             ...
# 3807  4940491  https://www.airbnb.com/rooms/4940491  20160104002432
# 3808  1844791  https://www.airbnb.com/rooms/1844791  20160104002432
# 3809  6120046  https://www.airbnb.com/rooms/6120046  20160104002432
# 3810   262764   https://www.airbnb.com/rooms/262764  20160104002432
# 3813  8101950  https://www.airbnb.com/rooms/8101950  20160104002432
#
#      last_scraped                                 name  \
# 1      2016-01-04   Bright & Airy Queen Anne Apartment
# ...

# %% [markdown]
# #### Sorting Data:
# #### o Sort the dataset by 'price' in descending order

# %%
sorted_price = df['price'].sort_values(ascending=False)
sorted_price
# Out:
# 3122    1000.0
# 1208     999.0
# 2        975.0
# 3443     950.0
# 1279     899.0
#          ...
# 2699      25.0
# 2900      25.0
# 2702      25.0
# 3580      22.0
# 53        20.0
# Name: price, Length: 3818, dtype: float64

# %% [markdown]
# #### 10. Rename Columns:
# ####  Rename the 'price' column to 'listing_price'.

# %%
df = df.rename(columns={'price': 'listing_price'})

# %%
df['listing_price']
# Out:
# 0        85.0
# 1       150.0
# 2       975.0
# 3       100.0
# 4       450.0
#         ...
# 3813    359.0
# 3814     79.0
# 3815     93.0
# 3816     99.0
# 3817     87.0
# Name: listing_price, Length: 3818, dtype: float64

# %% [markdown]
# #### 11. Value Counts:
# ####  Display the count of unique values in the 'room_type' column.

# %%
temp = df['room_type'].nunique()
temp
# Out:
# 3

# %% [markdown]
# #### 12. Subset Data:
# ####  Select and display the 'neighbourhood', 'room_type', and 'price' columns

# %%
subset_df = df[['neighbourhood', 'room_type', 'listing_price']]

# %%
subset_df
# Out:
#      neighbourhood        room_type  listing_price
# 0       Queen Anne  Entire home/apt           85.0
# 1       Queen Anne  Entire home/apt          150.0
# 2       Queen Anne  Entire home/apt          975.0
# 3       Queen Anne  Entire home/apt          100.0
# 4       Queen Anne  Entire home/apt          450.0
# ...            ...              ...            ...
# 3813       Fremont  Entire home/apt          359.0
# 3814   Portage Bay  Entire home/apt           79.0
# 3815           NaN  Entire home/apt           93.0
# 3816           NaN  Entire home/apt           99.0
# 3817    Queen Anne  Entire home/apt           87.0
#
# [3818 rows x 3 columns]

# %% [markdown]
# ## Medium Level (12 questions)

# %% [markdown]
# #### 1. Handling Missing Values:
# #### o Fill missing values in the 'reviews_per_month' column with the median of the column.

# %%
df['reviews_per_month'] = df['reviews_per_month'].fillna(df['reviews_per_month'].median())

# %%
df['reviews_per_month'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### 2. Data Grouping:
# #### o Group the dataset by 'neighbourhood' and calculate the mean price for each neighborhood.

# %%
df_neighbourhood = df.groupby('neighbourhood')

# %%
type(df_neighbourhood)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df_neighbourhood.size()
# Out:
# neighbourhood
# Alki               23
# Arbor Heights       3
# Atlantic           50
# Ballard           213
# Belltown          204
#                  ...
# Wallingford       143
# Wedgewood          15
# Westlake           12
# Windermere         10
# Yesler Terrace     12
# Length: 81, dtype: int64

# %%
df_neighbourhood = df.groupby('neighbourhood')['listing_price'].mean()

# %%
df_neighbourhood
# Out:
# neighbourhood
# Alki              196.652174
# Arbor Heights     118.000000
# Atlantic          116.280000
# Ballard           123.615023
# Belltown          166.627451
#                      ...
# Wallingford       131.335664
# Wedgewood         106.666667
# Westlake          197.000000
# Windermere        174.700000
# Yesler Terrace    141.083333
# Name: listing_price, Length: 81, dtype: float64

# %% [markdown]
# #### 3. Aggregating Data:
# #### o Aggregate the data to find the minimum, maximum, and average prices for each 'room_type'.

# %%
df['room_type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room'], dtype=object)

# %%
minimum_price = df.groupby('room_type')['listing_price'].min()
minimum_price
# Out:
# room_type
# Entire home/apt    39.0
# Private room       20.0
# Shared room        22.0
# Name: listing_price, dtype: float64

# %%
maximum_price = df.groupby('room_type')['listing_price'].max()
maximum_price
# Out:
# room_type
# Entire home/apt    1000.0
# Private room        399.0
# Shared room         118.0
# Name: listing_price, dtype: float64

# %%
average_price = df.groupby('room_type')['listing_price'].mean()
average_price
# Out:
# room_type
# Entire home/apt    155.843369
# Private room        75.044828
# Shared room         47.547009
# Name: listing_price, dtype: float64

# %%
aggregated_data = pd.DataFrame({'Minimum Price': minimum_price, 'Maximum Price': maximum_price, 'Average Price': average_price})
aggregated_data
# Out:
#                  Minimum Price  Maximum Price  Average Price
# room_type
# Entire home/apt           39.0         1000.0     155.843369
# Private room              20.0          399.0      75.044828
# Shared room               22.0          118.0      47.547009

# %% [markdown]
# #### 4. Filtering by Date:
# #### o Filter the dataset to show listings that were last reviewed after '2015-01-01'.

# %%
df['last_review']
# Out:
# 0       2016-01-02
# 1       2015-12-29
# 2       2015-09-03
# 3              NaN
# 4       2015-10-24
#            ...
# 3813    2015-09-27
# 3814    2015-12-24
# 3815           NaN
# 3816           NaN
# 3817           NaN
# Name: last_review, Length: 3818, dtype: object

# %%
df['last_review'] = df['last_review'].str.replace('-','')

# %%
df['last_review'] = pd.to_numeric(df['last_review'])

# %%
df['last_review'].max()
# Out:
# 20160103.0

# %%
df_filter = df[df['last_review'] > 20150101]
df_filter
# Out:
#            id                           listing_url       scrape_id  \
# 0      241032   https://www.airbnb.com/rooms/241032  20160104002432
# 1      953595   https://www.airbnb.com/rooms/953595  20160104002432
# 2     3308979  https://www.airbnb.com/rooms/3308979  20160104002432
# 4      278830   https://www.airbnb.com/rooms/278830  20160104002432
# 5     5956968  https://www.airbnb.com/rooms/5956968  20160104002432
# ...       ...                                   ...             ...
# 3810   262764   https://www.airbnb.com/rooms/262764  20160104002432
# 3811  8578490  https://www.airbnb.com/rooms/8578490  20160104002432
# 3812  3383329  https://www.airbnb.com/rooms/3383329  20160104002432
# 3813  8101950  https://www.airbnb.com/rooms/8101950  20160104002432
# 3814  8902327  https://www.airbnb.com/rooms/8902327  20160104002432
#
#      last_scraped                                 name  \
# 0      2016-01-04         Stylish Queen Anne Apartment
# ...

# %% [markdown]
# #### 5. New Feature Creation:
# #### o Create a new column called 'price_per_accommodates' by dividing 'price' by 'accommodates'.

# %%
df['listing_price']
# Out:
# 0        85.0
# 1       150.0
# 2       975.0
# 3       100.0
# 4       450.0
#         ...
# 3813    359.0
# 3814     79.0
# 3815     93.0
# 3816     99.0
# 3817     87.0
# Name: listing_price, Length: 3818, dtype: float64

# %%
df['accommodates']
# Out:
# 0        4
# 1        4
# 2       11
# 3        3
# 4        6
#         ..
# 3813     6
# 3814     4
# 3815     2
# 3816     2
# 3817     3
# Name: accommodates, Length: 3818, dtype: int64

# %%
df['price_per_accommodates'] = df['listing_price'] / df['accommodates']
df['price_per_accommodates']
# Out:
# 0       21.250000
# 1       37.500000
# 2       88.636364
# 3       33.333333
# 4       75.000000
#           ...
# 3813    59.833333
# 3814    19.750000
# 3815    46.500000
# 3816    49.500000
# 3817    29.000000
# Name: price_per_accommodates, Length: 3818, dtype: float64

# %% [markdown]
# #### 6. Convert Data Types:
# #### o Convert the 'price' column to a float after removing special characters (like $).

# %%
df['price'] = df.str.replace('$', '')

# %% [markdown]
# #### 7. String Operations:
# #### o Extract the first word from the 'name' column and create a new column called 'listing_name_first_word'

# %%
df['name']
# Out:
# 0              Stylish Queen Anne Apartment
# 1        Bright & Airy Queen Anne Apartment
# 2       New Modern House-Amazing water view
# 3                        Queen Anne Chateau
# 4            Charming craftsman 3 bdm house
#                        ...
# 3813     3BR Mountain View House in Seattle
# 3814      Portage Bay View!-One Bedroom Apt
# 3815      Private apartment view of Lake WA
# 3816      Amazing View with Modern Comfort!
# 3817              Large Lakefront Apartment
# Name: name, Length: 3818, dtype: object

# %%
df['listing_name_first_word'] = df['name'].str.split().str[0]
df['listing_name_first_word']
# Out:
# 0        Stylish
# 1         Bright
# 2            New
# 3          Queen
# 4       Charming
#           ...
# 3813         3BR
# 3814     Portage
# 3815     Private
# 3816     Amazing
# 3817       Large
# Name: listing_name_first_word, Length: 3818, dtype: object

# %% [markdown]
# #### 8. Descriptive Statistics by Group:
# #### o Calculate the standard deviation of 'price' for each 'room_type'.

# %%
std_dev = df.groupby('room_type')['listing_price'].std()
std_dev
# Out:
# room_type
# Entire home/apt    96.551181
# Private room       34.603905
# Shared room        19.372704
# Name: listing_price, dtype: float64

# %% [markdown]
# #### 9. Find Outliers:
# #### o Identify listings with a price more than 3 standard deviations above the mean price.

# %%
df_stddev = df['listing_price'].std()
df_mean = df['listing_price'].mean()
print(df_mean)
print(df_stddev)
print(df_mean+3*df_stddev)
 # > m+3*std
temp_res = df[df['listing_price']> df_mean+3*df_stddev]
temp_res['listing_price']
# Out:
# 127.97616553169199
# 90.2500221614799
# 398.7262320161317
# 2       975.0
# 4       450.0
# 14      461.0
# 19      700.0
# 22      450.0
#         ...
# 3636    450.0
# 3678    500.0
# 3701    450.0
# 3747    400.0
# 3753    400.0
# Name: listing_price, Length: 81, dtype: float64

# %% [markdown]
# #### 10. Replace Values:
# ####  Replace all values in the 'neighbourhood' column where 'neighbourhood' is 'Downtown' with 'Downtown Seattle'.

# %%
df['neighbourhood'] = df['neighbourhood'].replace('Downtown', 'Downtown Seattle')

# %%
df['neighbourhood']
# Out:
# 0        Queen Anne
# 1        Queen Anne
# 2        Queen Anne
# 3        Queen Anne
# 4        Queen Anne
#            ...
# 3813        Fremont
# 3814    Portage Bay
# 3815            NaN
# 3816            NaN
# 3817     Queen Anne
# Name: neighbourhood, Length: 3818, dtype: object

# %% [markdown]
# #### 11. Pivot Table:
# ####  Create a pivot table showing the average price for each combination of 'room_type' and 'neighbourhood'.

# %%
pivot_table = df.groupby(['room_type', 'neighbourhood'])['listing_price'].mean()
pivot_table
# Out:
# room_type        neighbourhood
# Entire home/apt  Alki                   195.789474
#                  Arbor Heights          150.000000
#                  Atlantic               139.058824
#                  Ballard                153.876812
#                  Belltown               172.187500
#                                            ...
# Shared room      Queen Anne              39.000000
#                  Roosevelt               56.000000
#                  Stevens                 34.785714
#                  University District     53.888889
#                  Wallingford             40.833333
# Name: listing_price, Length: 178, dtype: float64

# %% [markdown]
# #### 12. Cumulative Sum:
# ####  Compute the cumulative sum of the 'number_of_reviews' column.

# %%
df['number_of_reviews'].sum()
# Out:
# 84849

# %% [markdown]
# #### Merging Datasets

# %%
df1 = pd.DataFrame({
    'ID': [1, 2, 3],
    'Name': ['Alice', 'Bob', 'Charlie']
})

df2 = pd.DataFrame({
    'ID': [1, 2, 4],
    'Score': [85, 90, 75]
})

# %%
df1
# Out:
#    ID     Name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie

# %%
df2
# Out:
#    ID  Score
# 0   1     85
# 1   2     90
# 2   4     75

# %%
merged_df = pd.merge(df1, df2, on='ID', how='inner')

# %%
merged_df
# Out:
#    ID   Name  Score
# 0   1  Alice     85
# 1   2    Bob     90
