# %% [markdown]
# ## Basic Questions (3 marks each)

# %%
import pandas as pd

# %% [markdown]
# #### 1. Load the dataset and display the first 5 rows.

# %%
df = pd.read_csv('./Dataset/supermarket_sales_Sheet1.csv')

# %% [markdown]
# #### 2. Check the datatype of each column in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %% [markdown]
# #### 3. Find the total number of transactions in the dataset.

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 0     1/5/2019  13:08      Ewallet  522.83                 4.761905
# 1     3/8/2019  10:29         Cash   76.40                 4.761905
# 2     3/3/2019  13:23  Credit card  324.31                 4.761905
# 3    1/27/2019  20:33      Ewallet  465.76                 4.761905
# 4     2/8/2019  10:37      Ewallet  604.17                 4.761905
# ..         ...    ...          ...     ...                      ...
# 995  1/29/2019  13:46      Ewallet   40.35                 4.761905
# 996   3/2/2019  17:16      Ewallet  973.80                 4.761905
# 997   2/9/2019  13:22         Cash   31.84                 4.761905
# 998  2/22/2019  15:33         Cash   65.82                 4.761905
# 999  2/18/2019  13:28         Cash  618.38                 4.761905
#
#      gross income  Rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 995        2.0175     6.2
# 996       48.6900     4.4
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [1000 rows x 17 columns]

# %%
df.shape
# Out:
# (1000, 17)

# %% [markdown]
# #### 4. List all the unique 'Customer Types' present in the dataset.

# %%
df['Customer type'].unique()
# Out:
# array(['Member', 'Normal'], dtype=object)

# %% [markdown]
# #### 5. Find the number of transactions where the payment method is 'Cash'."

# %%
df[df['Payment'] == 'Cash'].shape
# Out:
# (344, 17)

# %% [markdown]
# #### 7. Sort the dataset by 'Total' in descending order and display the top 5 rows

# %%
df = df.sort_values('Total')

# %%
df.head()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 822  784-21-9238      C  Naypyitaw        Member    Male    Sports and travel
# 629  308-39-1707      A     Yangon        Normal  Female  Fashion accessories
# 223  279-62-1445      C  Naypyitaw        Member  Female  Fashion accessories
# 443  192-98-7397      C  Naypyitaw        Normal    Male  Fashion accessories
# 402  236-86-3015      C  Naypyitaw        Member    Male   Home and lifestyle
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time      Payment  \
# 822       10.17         1  0.5085  10.6785   2/7/2019  14:15         Cash
# 629       12.09         1  0.6045  12.6945  1/26/2019  18:19  Credit card
# 223       12.54         1  0.6270  13.1670  2/21/2019  12:38         Cash
# 443       12.78         1  0.6390  13.4190   1/8/2019  14:11      Ewallet
# 402       13.98         1  0.6990  14.6790   2/4/2019  13:38      Ewallet
#
#       cogs  gross margin percentage  gross income  Rating
# 822  10.17                 4.761905        0.5085     5.9
# 629  12.09                 4.761905        0.6045     8.2
# 223  12.54                 4.761905        0.6270     8.2
# 443  12.78                 4.761905        0.6390     9.5
# 402  13.98                 4.761905        0.6990     9.8

# %% [markdown]
# #### 8. Find the total 'Quantity' sold for the product line 'Health and Beauty'.

# %%
df_filter = df[df['Product line'] == 'Health and beauty']

# %%
df_filter
# Out:
#       Invoice ID Branch       City Customer type  Gender       Product line  \
# 808  559-61-5987      B   Mandalay        Normal  Female  Health and beauty
# 69   382-03-4532      A     Yangon        Member  Female  Health and beauty
# 445  390-80-5128      B   Mandalay        Member  Female  Health and beauty
# 453  568-88-3448      A     Yangon        Normal    Male  Health and beauty
# 448  296-11-7041      B   Mandalay        Member  Female  Health and beauty
# ..           ...    ...        ...           ...     ...                ...
# 627  628-90-8624      B   Mandalay        Member    Male  Health and beauty
# 906  450-42-3339      C  Naypyitaw        Normal    Male  Health and beauty
# 158  743-04-1105      B   Mandalay        Member    Male  Health and beauty
# 96   766-85-7061      B   Mandalay        Normal    Male  Health and beauty
# 141  280-17-4359      C  Naypyitaw        Member    Male  Health and beauty
#
#      Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 808       17.75         1   0.8875   18.6375  1/14/2019  10:38         Cash
# 69        18.33         1   0.9165   19.2465   2/2/2019  18:50         Cash
# 445       19.15         1   0.9575   20.1075  1/28/2019  17:58  Credit card
# 453       25.00         1   1.2500   26.2500   3/3/2019  15:09      Ewallet
# 448       27.07         1   1.3535   28.4235  1/12/2019  20:07  Credit card
# ..          ...       ...      ...       ...        ...    ...          ...
# 627       82.58        10  41.2900  867.0900  3/14/2019  14:41         Cash
# 906       84.61        10  42.3050  888.4050   2/9/2019  18:58  Credit card
# 158       97.22         9  43.7490  918.7290  3/30/2019  14:43      Ewallet
# 96        87.87        10  43.9350  922.6350  3/29/2019  10:25      Ewallet
# 141       90.50        10  45.2500  950.2500  1/25/2019  13:48         Cash
#
#        cogs  gross margin percentage  gross income  Rating
# 808   17.75                 4.761905        0.8875     8.6
# 69    18.33                 4.761905        0.9165     4.3
# 445   19.15                 4.761905        0.9575     9.5
# 453   25.00                 4.761905        1.2500     5.5
# 448   27.07                 4.761905        1.3535     5.3
# ..      ...                      ...           ...     ...
# 627  825.80                 4.761905       41.2900     5.0
# 906  846.10                 4.761905       42.3050     8.8
# 158  874.98                 4.761905       43.7490     6.0
# 96   878.70                 4.761905       43.9350     5.1
# 141  905.00                 4.761905       45.2500     8.1
#
# [152 rows x 17 columns]

# %%
df_filter['Quantity'].sum()
# Out:
# 854

# %% [markdown]
# #### 9. Check for any missing values in the dataset and display the columns with missing values, if any.

# %%
df.isnull().size
# Out:
# 17000

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.isnull()
# Out:
#      Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 822       False   False  False          False   False         False
# 629       False   False  False          False   False         False
# 223       False   False  False          False   False         False
# 443       False   False  False          False   False         False
# 402       False   False  False          False   False         False
# ..          ...     ...    ...            ...     ...           ...
# 996       False   False  False          False   False         False
# 699       False   False  False          False   False         False
# 557       False   False  False          False   False         False
# 167       False   False  False          False   False         False
# 350       False   False  False          False   False         False
#
#      Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs  \
# 822       False     False   False  False  False  False    False  False
# 629       False     False   False  False  False  False    False  False
# 223       False     False   False  False  False  False    False  False
# 443       False     False   False  False  False  False    False  False
# 402       False     False   False  False  False  False    False  False
# ..          ...       ...     ...    ...    ...    ...      ...    ...
# 996       False     False   False  False  False  False    False  False
# 699       False     False   False  False  False  False    False  False
# 557       False     False   False  False  False  False    False  False
# 167       False     False   False  False  False  False    False  False
# 350       False     False   False  False  False  False    False  False
#
#      gross margin percentage  gross income  Rating
# 822                    False         False   False
# 629                    False         False   False
# 223                    False         False   False
# 443                    False         False   False
# 402                    False         False   False
# ..                       ...           ...     ...
# 996                    False         False   False
# 699                    False         False   False
# 557                    False         False   False
# 167                    False         False   False
# 350                    False         False   False
#
# [1000 rows x 17 columns]

# %%
df.columns.isnull().shape
# Out:
# (17,)

# %% [markdown]
# #### 10. Convert the 'Date' column into a datetime format.

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 822 to 350
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(8)
# memory usage: 140.6+ KB

# %% [markdown]
# ## Intermediate Questions (5 marks each)

# %% [markdown]
# #### 1. Calculate the average 'Total' for each 'Product Line'

# %%
df.groupby('Product line')['Total'].mean()
# Out:
# Product line
# Electronic accessories    319.632538
# Fashion accessories       305.089298
# Food and beverages        322.671517
# Health and beauty         323.643020
# Home and lifestyle        336.636956
# Sports and travel         332.065220
# Name: Total, dtype: float64

# %% [markdown]
# #### 2. Group the data by 'City' and find the sum of 'Gross Income' for each city

# %%
df.groupby('City')['gross income'].sum()
# Out:
# City
# Mandalay     5057.0320
# Naypyitaw    5265.1765
# Yangon       5057.1605
# Name: gross income, dtype: float64

# %% [markdown]
# #### 3. Create a new column 'Total Including Tax' by adding 'Tax 5%' to 'Total'.

# %%
df['total_including_tax'] = df['Tax 5%'] + df['Total']

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 822  784-21-9238      C  Naypyitaw        Member    Male    Sports and travel
# 629  308-39-1707      A     Yangon        Normal  Female  Fashion accessories
# 223  279-62-1445      C  Naypyitaw        Member  Female  Fashion accessories
# 443  192-98-7397      C  Naypyitaw        Normal    Male  Fashion accessories
# 402  236-86-3015      C  Naypyitaw        Member    Male   Home and lifestyle
# ..           ...    ...        ...           ...     ...                  ...
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 699  751-41-9720      C  Naypyitaw        Normal    Male   Home and lifestyle
# 557  283-26-5248      C  Naypyitaw        Member  Female   Food and beverages
# 167  687-47-8271      A     Yangon        Normal    Male  Fashion accessories
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# 822       10.17         1   0.5085    10.6785 2019-02-07  14:15         Cash
# 629       12.09         1   0.6045    12.6945 2019-01-26  18:19  Credit card
# 223       12.54         1   0.6270    13.1670 2019-02-21  12:38         Cash
# 443       12.78         1   0.6390    13.4190 2019-01-08  14:11      Ewallet
# 402       13.98         1   0.6990    14.6790 2019-02-04  13:38      Ewallet
# ..          ...       ...      ...        ...        ...    ...          ...
# 996       97.38        10  48.6900  1022.4900 2019-03-02  17:16      Ewallet
# 699       97.50        10  48.7500  1023.7500 2019-01-12  16:18      Ewallet
# 557       98.52        10  49.2600  1034.4600 2019-01-30  20:23      Ewallet
# 167       98.98        10  49.4900  1039.2900 2019-02-08  16:20  Credit card
# 350       99.30        10  49.6500  1042.6500 2019-02-15  14:53  Credit card
#
#        cogs  gross margin percentage  gross income  Rating  \
# 822   10.17                 4.761905        0.5085     5.9
# 629   12.09                 4.761905        0.6045     8.2
# 223   12.54                 4.761905        0.6270     8.2
# 443   12.78                 4.761905        0.6390     9.5
# 402   13.98                 4.761905        0.6990     9.8
# ..      ...                      ...           ...     ...
# 996  973.80                 4.761905       48.6900     4.4
# 699  975.00                 4.761905       48.7500     8.0
# 557  985.20                 4.761905       49.2600     4.5
# 167  989.80                 4.761905       49.4900     8.7
# 350  993.00                 4.761905       49.6500     6.6
#
#      total_including_tax
# 822               11.187
# 629               13.299
# 223               13.794
# 443               14.058
# 402               15.378
# ..                   ...
# 996             1071.180
# 699             1072.500
# 557             1083.720
# 167             1088.780
# 350             1092.300
#
# [1000 rows x 18 columns]

# %% [markdown]
# #### 4. Find the total number of transactions made by 'Members' and 'Normal' customers.

# %%
df['Customer type'].value_counts()
# Out:
# Customer type
# Member    501
# Normal    499
# Name: count, dtype: int64

# %% [markdown]
# #### 5. Filter the dataset to show transactions where the 'Payment' method is 'Ewallet' and the 'Total' is greater than 500.

# %%
df_filter = df[(df['Payment'] == 'Ewallet') & (df['Total'] > 500)]
df_filter
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 854  160-22-2687      A     Yangon        Member  Female    Health and beauty
# 700  626-43-7888      C  Naypyitaw        Normal  Female  Fashion accessories
# 375  667-23-5919      A     Yangon        Member  Female  Fashion accessories
# 343  416-13-5917      C  Naypyitaw        Normal  Female   Food and beverages
# 388  394-41-0748      C  Naypyitaw        Member  Female  Fashion accessories
# ..           ...    ...        ...           ...     ...                  ...
# 435  751-69-0068      C  Naypyitaw        Normal    Male    Sports and travel
# 429  325-77-6186      A     Yangon        Member  Female   Home and lifestyle
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 699  751-41-9720      C  Naypyitaw        Normal    Male   Home and lifestyle
# 557  283-26-5248      C  Naypyitaw        Member  Female   Food and beverages
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 854       95.95         5  23.9875   503.7375 2019-01-23  14:21  Ewallet
# 700       60.41         8  24.1640   507.4440 2019-02-07  12:23  Ewallet
# 375       96.70         5  24.1750   507.6750 2019-01-14  12:52  Ewallet
# 343       97.03         5  24.2575   509.4075 2019-01-30  16:24  Ewallet
# 388       54.07         9  24.3315   510.9615 2019-01-27  14:55  Ewallet
# ..          ...       ...      ...        ...        ...    ...      ...
# 435       99.24         9  44.6580   937.8180 2019-03-19  19:09  Ewallet
# 429       90.65        10  45.3250   951.8250 2019-03-08  10:53  Ewallet
# 996       97.38        10  48.6900  1022.4900 2019-03-02  17:16  Ewallet
# 699       97.50        10  48.7500  1023.7500 2019-01-12  16:18  Ewallet
# 557       98.52        10  49.2600  1034.4600 2019-01-30  20:23  Ewallet
#
#        cogs  gross margin percentage  gross income  Rating  \
# 854  479.75                 4.761905       23.9875     8.8
# 700  483.28                 4.761905       24.1640     9.6
# 375  483.50                 4.761905       24.1750     7.0
# 343  485.15                 4.761905       24.2575     9.3
# 388  486.63                 4.761905       24.3315     9.5
# ..      ...                      ...           ...     ...
# 435  893.16                 4.761905       44.6580     9.0
# 429  906.50                 4.761905       45.3250     7.3
# 996  973.80                 4.761905       48.6900     4.4
# 699  975.00                 4.761905       48.7500     8.0
# 557  985.20                 4.761905       49.2600     4.5
#
#      total_including_tax
# 854              527.725
# 700              531.608
# 375              531.850
# 343              533.665
# 388              535.293
# ..                   ...
# 435              982.476
# 429              997.150
# 996             1071.180
# 699             1072.500
# 557             1083.720
#
# [75 rows x 18 columns]

# %% [markdown]
# #### 6. Find the highest 'Rating' received for each 'Product Line'

# %%
df.groupby('Product line')['Rating'].max()
# Out:
# Product line
# Electronic accessories    10.0
# Fashion accessories        9.9
# Food and beverages         9.9
# Health and beauty         10.0
# Home and lifestyle         9.9
# Sports and travel         10.0
# Name: Rating, dtype: float64

# %% [markdown]
# #### 7. Calculate the total 'Quantity' of products sold for each 'Branch'.

# %%
df.groupby('Branch')['Quantity'].sum()
# Out:
# Branch
# A    1859
# B    1820
# C    1831
# Name: Quantity, dtype: int64

# %% [markdown]
# #### 8. Display the top 3 cities with the highest total sales ('Total').

# %%
df_filter = df.sort_values('Total' , ascending = False)

# %%
df_filter.head(3)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
# 167  687-47-8271      A     Yangon        Normal    Male  Fashion accessories
# 557  283-26-5248      C  Naypyitaw        Member  Female   Food and beverages
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time      Payment  \
# 350       99.30        10   49.65  1042.65 2019-02-15  14:53  Credit card
# 167       98.98        10   49.49  1039.29 2019-02-08  16:20  Credit card
# 557       98.52        10   49.26  1034.46 2019-01-30  20:23      Ewallet
#
#       cogs  gross margin percentage  gross income  Rating  total_including_tax
# 350  993.0                 4.761905         49.65     6.6              1092.30
# 167  989.8                 4.761905         49.49     8.7              1088.78
# 557  985.2                 4.761905         49.26     4.5              1083.72

# %% [markdown]
# #### 9. Replace any missing values in the 'Rating' column with the median of the 'Rating' column.

# %%
df['Rating'] = df['Rating'].fillna(df['Rating'].median())

# %% [markdown]
# #### 10. Standardize the format of the 'Date' column and check for any inconsistencies in the date format.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 822 to 350
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
#  17  total_including_tax      1000 non-null   float64
# dtypes: datetime64[ns](1), float64(8), int64(1), object(8)
# memory usage: 148.4+ KB

# %% [markdown]
# ## Advanced Questions (10 marks each)

# %% [markdown]
# #### 1. Calculate the correlation between 'Quantity' and 'Total'.

# %% [markdown]
# #### 2. Group the data by 'Branch' and 'Customer Type' and find the average 'Rating' for each group.

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'total_including_tax'],
#       dtype='object')

# %%
df.groupby(['Branch', 'Customer type'])['Rating'].mean()
# Out:
# Branch  Customer type
# A       Member           6.998802
#         Normal           7.054335
# B       Member           6.770303
#         Normal           6.865269
# C       Member           7.048521
#         Normal           7.098742
# Name: Rating, dtype: float64

# %% [markdown]
# #### 3. Plot a bar chart showing the total sales ('Total') for each 'Product Line'.

# %%
# not done yet

# %% [markdown]
# #### 4. Determine the top 3 'Product Lines' with the highest 'Gross Income'.

# %%
df_filter = df.sort_values('gross income', ascending = False)

# %%
df_filter['Product line'].head(3)
# Out:
# 350    Fashion accessories
# 167    Fashion accessories
# 557     Food and beverages
# Name: Product line, dtype: object

# %% [markdown]
# #### 5. Analyze patterns in the use of 'Payment' methods across different 'Customer Types'.

# %% [markdown]
# #### 6. Calculate the cumulative sum of 'Gross Income' over time and plot it

# %%
df['gross income'].sum()
# Out:
# 15379.369

# %% [markdown]
# #### 7. Perform a time-series analysis to find the monthly trend in sales by grouping transactions by 'Date'.
