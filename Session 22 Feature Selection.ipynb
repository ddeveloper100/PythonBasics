# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Generating Data

# %%
# Choose a mean,standard deviation, and number of samples

def create_ages(mu=50,sigma=13,num_samples=100,seed=42):

    # Set a random seed in the same cell as the random call to get the same values as us
    # We set seed to 42 (42 is an arbitrary choice from Hitchhiker's Guide to the Galaxy)
    np.random.seed(seed)

    sample_ages = np.random.normal(loc=mu,scale=sigma,size=num_samples)
    sample_ages = np.round(sample_ages,decimals=0)
    
    return sample_ages

# %%
sample = create_ages()

# %%
sample
# Out:
# array([56., 48., 58., 70., 47., 47., 71., 60., 44., 57., 44., 44., 53.,
#        25., 28., 43., 37., 54., 38., 32., 69., 47., 51., 31., 43., 51.,
#        35., 55., 42., 46., 42., 74., 50., 36., 61., 34., 53., 25., 33.,
#        53., 60., 52., 48., 46., 31., 41., 44., 64., 54., 27., 54., 45.,
#        41., 58., 63., 62., 39., 46., 54., 63., 44., 48., 36., 34., 61.,
#        68., 49., 63., 55., 42., 55., 70., 50., 70., 16., 61., 51., 46.,
#        51., 24., 47., 55., 69., 43., 39., 43., 62., 54., 43., 57., 51.,
#        63., 41., 46., 45., 31., 54., 53., 50., 47.])

# %% [markdown]
# ### Visualize and Describe the Data

# %%
sns.displot(sample,bins=10,kde=False)

# %%
sns.boxplot(sample)
# Out:
# <Axes: >

# %%
ser = pd.Series(sample)
ser.describe()
# Out:
# count    100.00000
# mean      48.66000
# std       11.82039
# min       16.00000
# 25%       42.00000
# 50%       48.00000
# 75%       55.25000
# max       74.00000
# dtype: float64

# %% [markdown]
# ### Trimming or Fixing Based Off Domain Knowledge
# If we know we're dealing with a dataset pertaining to voting age (18 years old in the USA), then it makes sense to either drop anything less than that OR fix values lower than 18 and push them up to 18.

# %%
ser[ser > 18]
# Out:
# 0     56.0
# 1     48.0
# 2     58.0
# 3     70.0
# 4     47.0
#       ...
# 95    31.0
# 96    54.0
# 97    53.0
# 98    50.0
# 99    47.0
# Length: 99, dtype: float64

# %%
# It dropped one person
len(ser[ser > 18])
# Out:
# 99

# %%
def fix_values(age):
    
    if age < 18:
        return 18
    else:
        return age

# %%
# "Fixes" one person's age
ser.apply(fix_values)
# Out:
# 0     56.0
# 1     48.0
# 2     58.0
# 3     70.0
# 4     47.0
#       ...
# 95    31.0
# 96    54.0
# 97    53.0
# 98    50.0
# 99    47.0
# Length: 100, dtype: float64

# %%
len(ser.apply(fix_values))
# Out:
# 100

# %%
# Example DataFrame
data = {
    'feature1': [10, 20, 30, 40, 50],
    'feature2': [3, 5, 2, 8, 7],
    'feature3': [10, 8, 6, 4, 2],
    'target':    [100, 200, 300, 400, 500]
}
df = pd.DataFrame(data)

# 1. Correlation of all features with the target
correlations = df.drop(columns='target').corrwith(df['target'])
print("Correlation of each feature with target:\n", correlations)

# 2. Correlation of a single feature (e.g., 'feature1') with the target
corr_feature1_target = df['feature1'].corr(df['target'])
print("\nCorrelation of feature1 with target:", corr_feature1_target)
# Out:
# Correlation of each feature with target:
#  feature1    1.000000
# feature2    0.682191
# feature3   -1.000000
# dtype: float64
#
# Correlation of feature1 with target: 1.0

# %% [markdown]
# ### Ames Data Set
# Let's explore any extreme outliers in our Ames Housing Data Set

# %%
df = pd.read_csv("./Archive/Machine Learning/Dataset/Ames_Housing_Data.csv")

# %%
df.shape
# Out:
# (2930, 81)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PID              2930 non-null   int64
#  1   MS SubClass      2930 non-null   int64
#  2   MS Zoning        2930 non-null   object
#  3   Lot Frontage     2440 non-null   float64
#  4   Lot Area         2930 non-null   int64
#  5   Street           2930 non-null   object
#  6   Alley            198 non-null    object
#  7   Lot Shape        2930 non-null   object
#  8   Land Contour     2930 non-null   object
#  9   Utilities        2930 non-null   object
#  10  Lot Config       2930 non-null   object
#  11  Land Slope       2930 non-null   object
#  12  Neighborhood     2930 non-null   object
#  13  Condition 1      2930 non-null   object
#  14  Condition 2      2930 non-null   object
#  15  Bldg Type        2930 non-null   object
# ...

# %%
df
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0     526301100           20        RL         141.0     31770   Pave   NaN
# 1     526350040           20        RH          80.0     11622   Pave   NaN
# 2     526351010           20        RL          81.0     14267   Pave   NaN
# 3     526353030           20        RL          93.0     11160   Pave   NaN
# 4     527105010           60        RL          74.0     13830   Pave   NaN
# ...         ...          ...       ...           ...       ...    ...   ...
# 2925  923275080           80        RL          37.0      7937   Pave   NaN
# 2926  923276100           20        RL           NaN      8885   Pave   NaN
# 2927  923400125           85        RL          62.0     10441   Pave   NaN
# 2928  924100070           20        RL          77.0     10010   Pave   NaN
# 2929  924151050           60        RL          74.0      9627   Pave   NaN
#
# ...

# %%
# df.corr()

# %%
df.corr(numeric_only=True)
# Out:
#                       PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# PID              1.000000    -0.001281     -0.096918  0.034868     -0.263147
# MS SubClass     -0.001281     1.000000     -0.420135 -0.204613      0.039419
# Lot Frontage    -0.096918    -0.420135      1.000000  0.491313      0.212042
# Lot Area         0.034868    -0.204613      0.491313  1.000000      0.097188
# Overall Qual    -0.263147     0.039419      0.212042  0.097188      1.000000
# Overall Cond     0.104451    -0.067349     -0.074448 -0.034759     -0.094812
# Year Built      -0.343388     0.036579      0.121562  0.023258      0.597027
# Year Remod/Add  -0.157111     0.043397      0.091712  0.021682      0.569609
# Mas Vnr Area    -0.229283     0.002730      0.222407  0.126830      0.429418
# BsmtFin SF 1    -0.098375    -0.060075      0.215583  0.191555      0.284118
# BsmtFin SF 2    -0.001145    -0.070946      0.045999  0.083150     -0.041287
# ...

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
df.corr(numeric_only=True)['SalePrice'].sort_values()
# Out:
# PID               -0.246521
# Enclosed Porch    -0.128787
# Kitchen AbvGr     -0.119814
# Overall Cond      -0.101697
# MS SubClass       -0.085092
# Low Qual Fin SF   -0.037660
# Bsmt Half Bath    -0.035835
# Yr Sold           -0.030569
# Misc Val          -0.015691
# BsmtFin SF 2       0.005891
# 3Ssn Porch         0.032225
# Mo Sold            0.035259
# Pool Area          0.068403
# Screen Porch       0.112151
# Bedroom AbvGr      0.143913
# Bsmt Unf SF        0.182855
# Lot Area           0.266549
# 2nd Flr SF         0.269373
# Bsmt Full Bath     0.276050
# Half Bath          0.285056
# Open Porch SF      0.312951
# Wood Deck SF       0.327143
# Lot Frontage       0.357318
# BsmtFin SF 1       0.432914
# Fireplaces         0.474558
# TotRms AbvGrd      0.495474
# Mas Vnr Area       0.508285
# Garage Yr Blt      0.526965
# Year Remod/Add     0.532974
# Full Bath          0.545604
# Year Built         0.558426
# 1st Flr SF         0.621676
# Total Bsmt SF      0.632280
# ...

# %%
sns.histplot(df["SalePrice"],kde=True)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
sns.scatterplot(x='Overall Qual',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='Overall Qual', ylabel='SalePrice'>

# %%
df[(df['Overall Qual']>8) & (df['SalePrice']<200000)]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 1182  533350090           60        RL           NaN     24572   Pave   NaN
# 1498  908154235           60        RL         313.0     63887   Pave   NaN
# 2180  908154195           20        RL         128.0     39290   Pave   NaN
# 2181  908154205           60        RL         130.0     40094   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC Fence  \
# 1182       IR1          Lvl    AllPub  ...         0     NaN   NaN
# 1498       IR3          Bnk    AllPub  ...       480      Gd   NaN
# 2180       IR1          Bnk    AllPub  ...         0     NaN   NaN
# 2181       IR1          Bnk    AllPub  ...         0     NaN   NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  \
# 1182          NaN        0       6    2008        WD           Family
# 1498          NaN        0       1    2008        New         Partial
# ...

# %%
df.shape
# Out:
# (2930, 81)

# %%
sns.scatterplot(x='Gr Liv Area',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='Gr Liv Area', ylabel='SalePrice'>

# %%
df[(df['Gr Liv Area']>4000) & (df['SalePrice']<400000)]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 1498  908154235           60        RL         313.0     63887   Pave   NaN
# 2180  908154195           20        RL         128.0     39290   Pave   NaN
# 2181  908154205           60        RL         130.0     40094   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC Fence  \
# 1498       IR3          Bnk    AllPub  ...       480      Gd   NaN
# 2180       IR1          Bnk    AllPub  ...         0     NaN   NaN
# 2181       IR1          Bnk    AllPub  ...         0     NaN   NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  \
# 1498          NaN        0       1    2008        New         Partial
# 2180         Elev    17000      10    2007        New         Partial
# 2181          NaN        0      10    2007        New         Partial
#
#       SalePrice
# 1498     160000
# 2180     183850
# 2181     184750
#
# [3 rows x 81 columns]

# %%
df[(df['Gr Liv Area']>4000) & (df['SalePrice']<400000)].index
# Out:
# Index([1498, 2180, 2181], dtype='int64')

# %%
ind_drop = df[(df['Gr Liv Area']>4000) & (df['SalePrice']<400000)].index

# %%
df = df.drop(ind_drop,axis=0)

# %%
sns.scatterplot(x='Gr Liv Area',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='Gr Liv Area', ylabel='SalePrice'>

# %%
sns.scatterplot(x='Overall Qual',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='Overall Qual', ylabel='SalePrice'>

# %%
df.to_csv("./Archive/Machine Learning/Dataset/Ames_outliers_removed.csv",index=False)

# %%
df[(df['Gr Liv Area']>4000) & (df['SalePrice']>700000)]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 1760  528320050           60        RL         160.0     15623   Pave   NaN
# 1767  528351010           60        RL         104.0     21535   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence  \
# 1760       IR1          Lvl    AllPub  ...       555      Ex  MnPrv
# 1767       IR1          Lvl    AllPub  ...         0     NaN    NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  \
# 1760          NaN        0       7    2007        WD          Abnorml
# 1767          NaN        0       1    2007        WD           Normal
#
#       SalePrice
# 1760     745000
# 1767     755000
#
# [2 rows x 81 columns]

# %%
ind_drop = df[(df['Gr Liv Area']>4000) & (df['SalePrice']>700000)].index

# %%
ind_drop
# Out:
# Index([1760, 1767], dtype='int64')

# %%
df = df.drop(ind_drop, axis=0)

# %%
sns.scatterplot(x='Gr Liv Area',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='Gr Liv Area', ylabel='SalePrice'>

# %%
sns.scatterplot(x='Overall Qual',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='Overall Qual', ylabel='SalePrice'>

# %%
df.to_csv("./Archive/Machine Learning/Dataset/Ames_outliers_removed.csv",index=False)

# %% [markdown]
# # Dealing with Categorical Data
# Many machine learning models can not deal with categorical data set as strings. For example linear regression can not apply a a Beta Coefficent to colors like "red" or "blue". Instead we need to convert these categories into "dummy" variables, otherwise known as "one-hot" encoding.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snsZ

# %% [markdown]
# ## Data
# We will open the .csv file that has been "cleaned" to remove outliers and NaN from the previous lectures.

# %%
df = pd.read_csv("./Archive/Machine Learning/Dataset/Ames_NO_Missing_Data.csv")

# %%
zZzzzZzZzzzzzZZZZzzzzzzZzzzZZZzZzZZZzzzzZZZZzzzZzzZzZZzZzzzZzzzzzz
