# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px

# %%
pip install plotly_express
# Out:
# Collecting plotly_express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\programdata\anaconda3\lib\site-packages (from plotly_express) (0.12.2)
# Requirement already satisfied: pandas>=0.20.0 in c:\programdata\anaconda3\lib\site-packages (from plotly_express) (1.2.4)
# Collecting plotly>=4.1.0
#   Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
# Requirement already satisfied: numpy>=1.11 in c:\programdata\anaconda3\lib\site-packages (from plotly_express) (1.20.1)
# Requirement already satisfied: scipy>=0.18 in c:\programdata\anaconda3\lib\site-packages (from plotly_express) (1.6.2)
# Requirement already satisfied: patsy>=0.5 in c:\programdata\anaconda3\lib\site-packages (from plotly_express) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly_express) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly_express) (2021.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from patsy>=0.5->plotly_express) (1.15.0)
# Collecting narwhals>=1.15.1
#   Downloading narwhals-1.29.0-py3-none-any.whl (305 kB)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from plotly>=4.1.0->plotly_express) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->plotly>=4.1.0->plotly_express) (2.4.7)
# Installing collected packages: narwhals, plotly, plotly-express
# Successfully installed narwhals-1.29.0 plotly-6.0.0 plotly-express-0.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
fifa_matches_df = pd.read_csv('./matches.csv')
fifa_matches_df.sample(5)
# Out:
#         home_team             away_team  home_score  home_xg  home_penalty  \
# 266         Italy             Australia           1      NaN           NaN
# 708      Bulgaria           Netherlands           1      NaN           NaN
# 649         Spain              Honduras           1      NaN           NaN
# 535  West Germany  United Arab Emirates           5      NaN           NaN
# 709        Poland                 Italy           2      NaN           NaN
#
#      away_score  away_xg  away_penalty       home_manager     home_captain  \
# 266           0      NaN           NaN     Marcello Lippi              NaN
# 708           4      NaN           NaN    Hristo Mladenov     Hristo Bonev
# 649           1      NaN           NaN    Jose Santamaria    Luis Arconada
# 535           1      NaN           NaN  Franz Beckenbauer  Lothar Matthäus
# 709           1      NaN           NaN   Kazimierz Gorski  Kazimierz Deyna
#
#      ... home_penalty_shootout_miss_long away_penalty_shootout_miss_long  \
# 266  ...                             NaN                             NaN
# 708  ...                             NaN                             NaN
# 649  ...                             NaN                             NaN
# 535  ...                             NaN                             NaN
# 709  ...                             NaN                             NaN
#
#             home_red_card away_red_card home_yellow_red_card  \
# 266  Marco Materazzi · 50           NaN                  NaN
# 708                   NaN           NaN                  NaN
# 649                   NaN           NaN                  NaN
# 535                   NaN           NaN                  NaN
# 709                   NaN           NaN                  NaN
#
#     away_yellow_red_card                              home_yellow_card_long  \
# 266                  NaN  ['29&rsquor;|0:0|Fabio Grosso', '89&rsquor;|0:...
# 708                  NaN                    ['67&rsquor;|0:2|Georgi Denev']
# 649                  NaN                                                NaN
# 535                  NaN                  ['30&rsquor;|0:0|Andreas Brehme']
# 709                  NaN  ['25&rsquor;|0:0|Henryk Kasperczak', '84&rsquo...
#
#                                  away_yellow_card_long  \
# 266  ['23&rsquor;|0:0|Vince Grella', '49&rsquor;|0:...
# 708  ['5&rsquor;|0:0|Wim Jansen', '22&rsquor;|0:1|W...
# 649                                                NaN
# 535  ['26&rsquor;|0:0|Yousuf Hussain', '30&rsquor;|...
# 709              ['71&rsquor;|2:0|Roberto Boninsegna']
#
#                                home_substitute_in_long  \
# 266  ['46&rsquor;|0:0|Vincenzo Iaquinta|for Alberto...
# 708  ['46&rsquor;|0:2|Atanas Mihaylov|for Ivan Stoy...
# 649  ['46&rsquor;|0:1|Enrique Saura|for Joaquín', '...
# 535  ['46&rsquor;|2:1|Pierre Littbarski|for Thomas ...
# 709               ['78&rsquor;|2:0|Lesław Ćmikiewicz']
#
#                                away_substitute_in_long
# 266  ['81&rsquor;|0:0|John Aloisi|for Mile Sterjovs...
# 708  ['46&rsquor;|0:2|Rinus Israël|for Willem van H...
# 649  ['69&rsquor;|1:1|Carlos Orlando Caballero|for ...
# 535  ['82&rsquor;|5:1|Hassan Mohamed|for Khalid Ism...
# 709  ['33&rsquor;|0:0|Giuseppe Wilson|for Tarcisio ...
#
# [5 rows x 44 columns]

# %%
fifa_matches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 964 entries, 0 to 963
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   home_team                        964 non-null    object
#  1   away_team                        964 non-null    object
#  2   home_score                       964 non-null    int64
#  3   home_xg                          128 non-null    float64
#  4   home_penalty                     35 non-null     float64
#  5   away_score                       964 non-null    int64
#  6   away_xg                          128 non-null    float64
#  7   away_penalty                     35 non-null     float64
#  8   home_manager                     964 non-null    object
#  9   home_captain                     644 non-null    object
#  10  away_manager                     964 non-null    object
#  11  away_captain                     644 non-null    object
#  12  Attendance                       964 non-null    int64
#  13  Venue                            964 non-null    object
#  14  Officials                        709 non-null    object
#  15  Round                            964 non-null    object
#  16  Date                             964 non-null    object
#  17  Score                            964 non-null    object
#  18  Referee                          709 non-null    object
#  19  Notes                            73 non-null     object
#  20  Host                             964 non-null    object
#  21  Year                             964 non-null    int64
#  22  home_goal                        718 non-null    object
#  23  away_goal                        571 non-null    object
#  24  home_goal_long                   718 non-null    object
#  25  away_goal_long                   571 non-null    object
#  26  home_own_goal                    39 non-null     object
#  27  away_own_goal                    17 non-null     object
#  28  home_penalty_goal                116 non-null    object
#  29  away_penalty_goal                84 non-null     object
#  30  home_penalty_miss_long           6 non-null      object
#  31  away_penalty_miss_long           9 non-null      object
#  32  home_penalty_shootout_goal_long  34 non-null     object
#  33  away_penalty_shootout_goal_long  34 non-null     object
#  34  home_penalty_shootout_miss_long  24 non-null     object
#  35  away_penalty_shootout_miss_long  30 non-null     object
#  36  home_red_card                    51 non-null     object
#  37  away_red_card                    54 non-null     object
#  38  home_yellow_red_card             23 non-null     object
#  39  away_yellow_red_card             31 non-null     object
#  40  home_yellow_card_long            621 non-null    object
#  41  away_yellow_card_long            627 non-null    object
#  42  home_substitute_in_long          740 non-null    object
#  43  away_substitute_in_long          747 non-null    object
#  44  no_home_yellow_card_long         621 non-null    float64
#  45  no_away_yellow_card_long         627 non-null    float64
# dtypes: float64(6), int64(4), object(36)
# memory usage: 346.6+ KB

# %%
covid_df = pd.read_csv('./MentalHealthinPregnancyDuringCovid.csv')
covid_df.sample(5)
# Out:
#       OSF_ID  Maternal_Age    Household_Income    Maternal_Education  \
# 7847    7848          33.8           $200,000+        Masters degree
# 3056    3057          24.4     $70,000-$99,999   High school diploma
# 948      949          26.3  $100,000 -$124,999  Undergraduate degree
# 7185    7186          35.0  $175,000- $199,999  Undergraduate degree
# 734      735          41.0  $175,000- $199,999  Undergraduate degree
#
#       Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 7847                                  12.0            23.0
# 3056                                   9.0            18.0
# 948                                    2.0            13.0
# 7185                                   NaN             NaN
# 734                                    1.0            14.0
#
#       Gestational_Age_At_Birth Delivery_Date(converted to month and year)  \
# 7847                     40.43                                    Oct2020
# 3056                       NaN                                        NaN
# 948                      40.29                                    Sep2020
# 7185                       NaN                                        NaN
# 734                        NaN                                        NaN
#
#       Birth_Length  Birth_Weight Delivery_Mode NICU_Stay Language  \
# 7847          48.0        3374.0     Vaginally        No   French
# 3056           NaN           NaN           NaN       NaN  English
# 948           49.0        3289.0     Vaginally        No   French
# 7185           NaN           NaN           NaN       NaN  English
# 734            NaN           NaN           NaN       NaN  English
#
#       Threaten_Life  Threaten_Baby_Danger  Threaten_Baby_Harm
# 7847           25.0                  37.0                50.0
# 3056            5.0                   7.0                50.0
# 948            31.0                  64.0                60.0
# 7185            NaN                   NaN                 NaN
# 734            51.0                   6.0                 5.0

# %% [markdown]
# 1. Bar Plot: Show the total number of goals scored by each team (home and away
# combined). (fifa_matches dataset)

# %%
home_df = fifa_matches_df[['home_team', 'home_score']].rename(
    columns={'home_team': 'team', 'home_score': 'score'}
)
away_df = fifa_matches_df[['away_team', 'away_score']].rename(
    columns={'away_team': 'team', 'away_score': 'score'}
)

# Combine both DataFrames and aggregate scores per team
combined_df = pd.concat([home_df, away_df], ignore_index=True)
team_scores = combined_df.groupby('team', as_index=False)['score'].sum()

# Plot the data using seaborn's barplot
plt.figure(figsize=(12, 5))
sns.barplot(data=team_scores, x='team', y='score')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# 2. Bar Plot: Show the number of yellow cards received by each team during the
# tournament. (fifa_matches dataset)

# %%
# Compute the number of yellow cards for home and away teams
fifa_matches_df['no_home_yellow_card_long'] = fifa_matches_df['home_yellow_card_long'].str.split(",").str.len()
fifa_matches_df['no_away_yellow_card_long'] = fifa_matches_df['away_yellow_card_long'].str.split(",").str.len()

# Create DataFrames for home and away teams with consistent column names
home_team_df = fifa_matches_df[['home_team', 'no_home_yellow_card_long']].rename(
    columns={'home_team': 'team', 'no_home_yellow_card_long': 'total_yellow_card'}
)
away_team_df = fifa_matches_df[['away_team', 'no_away_yellow_card_long']].rename(
    columns={'away_team': 'team', 'no_away_yellow_card_long': 'total_yellow_card'}
)

# Combine both DataFrames and sum the yellow cards per team
combined_df = pd.concat([home_team_df, away_team_df], ignore_index=True)
team_yellow_cards = combined_df.groupby('team', as_index=False)['total_yellow_card'].sum()

# Plot the aggregated yellow cards using seaborn's barplot
plt.figure(figsize=(12, 5))
sns.barplot(data=team_yellow_cards, x='team', y='total_yellow_card')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Box Plot: Show the distribution of scores (home_score and away_score) for all teams.
# (Use subplots of matplotlib or seaborn). (fifa_matches dataset)

# %%
home_team_df = fifa_matches_df[['home_team', 'home_score']]
home_team_df = home_team_df.rename(columns = {'home_team': 'team', 'home_score': 'score'})
away_team_df = fifa_matches_df[['away_team', 'away_score']]
away_team_df = away_team_df.rename(columns = {'away_team': 'team', 'away_score': 'score'})

temp_df = pd.concat([home_team_df, away_team_df])

fig, ax = plt.subplots(figsize=(12, 5))
sns.boxplot(data=temp_df, x='team', y = 'score', ax=ax )

plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# 4. Stacked Bar Plot: Display the number of wins, draws, and losses for all home teams.
# (fifa_matches dataset)

# %%
fifa_matches_df['home_total_score'] = fifa_matches_df['home_score'].fillna(0) + fifa_matches_df['home_penalty'].fillna(0)
fifa_matches_df['away_total_score'] = fifa_matches_df['away_score'].fillna(0) + fifa_matches_df['away_penalty'].fillna(0)

fifa_matches_df.loc[(fifa_matches_df['home_total_score'] > fifa_matches_df['away_total_score']), 'Match_Result'] = 'win'
fifa_matches_df.loc[(fifa_matches_df['home_total_score'] < fifa_matches_df['away_total_score']), 'Match_Result'] = 'loss'
fifa_matches_df.loc[(fifa_matches_df['home_total_score'] == fifa_matches_df['away_total_score']), 'Match_Result'] = 'draw'

# fifa_matches_df['Match_Result'].groupby()

# fifa_matches_df.groupby(['Match_Result']).count()
fig, ax = plt.subplots(figsize=(12, 5))
sns.histplot(data=fifa_matches_df, x='home_team', hue='Match_Result',multiple="stack", ax=ax)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# 5. Pie Chart: Show the number of times country becomes champion. (fifa_matches dataset)

# %%
temp_df = fifa_matches_df[['home_team', 'away_team', 'Round', 'home_total_score', 'away_total_score']]
temp_df = temp_df[fifa_matches_df['Round'] == 'Final']

temp_df.loc[temp_df['home_total_score']>temp_df['away_total_score'], 'winner_team'] = temp_df['home_team']
temp_df.loc[temp_df['home_total_score']<temp_df['away_total_score'], 'winner_team'] = temp_df['away_team']

temp_df = temp_df.groupby('winner_team').count()

plt.pie(temp_df['Round'], labels=temp_df.index, autopct='%0.1f%%')
plt.show()

# %% [markdown]
# 6. Pie Chart: Show the number of times country becomes runner up. (fifa_matches dataset)

# %%
temp_df = fifa_matches_df[['home_team', 'away_team', 'Round', 'home_total_score', 'away_total_score']]
temp_df = temp_df[fifa_matches_df['Round'] == 'Final']

temp_df.loc[temp_df['home_total_score']>temp_df['away_total_score'], 'runner_up_team'] = temp_df['away_team']
temp_df.loc[temp_df['home_total_score']<temp_df['away_total_score'], 'runner_up_team'] = temp_df['home_team']

temp_df = temp_df.groupby('runner_up_team').count()

plt.pie(temp_df['Round'], labels=temp_df.index, autopct='%0.1f%%')
plt.show()

# %% [markdown]
# 7. Subplots: Visualizing Numerical Data Distributions Using KDE Plots. (covid dataset)

# %%
covid_df_numerics_only = covid_df.select_dtypes(include=np.number)
covid_df_numerics_only = covid_df_numerics_only.fillna(0)

fig, axes = plt.subplots(figsize=(20,10), ncols=5, nrows=2)

for i in np.arange(2):
    for j in np.arange(5):
        column_index = (i+1) * (j+1)
        column_name = covid_df_numerics_only.columns[column_index-1]
        sns.kdeplot(covid_df_numerics_only[column_name], ax=axes[i, j])

# %% [markdown]
# 8. Scatter Plot: Plot Birth_Weight against Birth_Length to visualize any relationship
# between the two variables. . (covid dataset)

# %%
covid_df['Birth_Length'] = covid_df['Birth_Length'].fillna(0)
covid_df['Birth_Weight'] = covid_df['Birth_Weight'].fillna(0)

sns.scatterplot(data=covid_df, x='Birth_Length', y='Birth_Weight')
plt.show()

# %% [markdown]
# 9. 3D Scatter Plot: Create a 3D scatter plot to visualize the relationship between
# Maternal_Age, Gestational_Age_At_Birth, and Birth_Weight. . (covid dataset)

# %%
covid_df['Maternal_Age'] = covid_df['Maternal_Age'].fillna(0)
covid_df['Gestational_Age_At_Birth'] = covid_df['Gestational_Age_At_Birth'].fillna(0)
covid_df['Birth_Weight'] = covid_df['Birth_Weight'].fillna(0)

fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(projection='3d')

ax.scatter(covid_df['Maternal_Age'], covid_df['Birth_Weight'], covid_df['Gestational_Age_At_Birth'])
ax.set_xlabel('Maternal_Age')
ax.set_ylabel('Gestational_Age_At_Birth')
ax.set_zlabel('Birth_Weight')
# Out:
# Text(0.5, 0, 'Birth_Weight')

# %% [markdown]
# 10. Subplots with Categorical Hue: Create subplots that compare Maternal_Age,
# Birth_Length, and Birth_Weight while coloring points based on Household_Income
# categories. (covid dataset)

# %%
fig, axes = plt.subplots(3, 1, figsize=(15, 15))
sns.scatterplot(ax=axes[0], data=covid_df, x='Maternal_Age', y='Birth_Length', hue='Household_Income')
sns.scatterplot(ax=axes[1], data=covid_df, x='Birth_Length', y='Birth_Weight', hue='Household_Income')
sns.scatterplot(ax=axes[2], data=covid_df, x='Birth_Weight', y='Maternal_Age', hue='Household_Income')
plt.show()

# %% [markdown]
# 11. Create a pairplot of the dataset that includes Maternal_Age, Birth_Length, Birth_Weight,
# and Gestational_Age_At_Birth as the variables to compare. Add the hue parameter to
# color the plots based on Household_Income categories.

# %%
temp_df = covid_df[['Maternal_Age', 'Birth_Length', 'Birth_Weight', 'Gestational_Age_At_Birth', 'Household_Income']]

sns.pairplot(temp_df, hue='Household_Income')

# %% [markdown]
# 12. Use JointGrid to create a customized grid showing the relationship between Birth_Length
# and Gestational_Age_At_Birth (convert weeks into months one month=4.33 week). Add
# scatter plots to the joint axes and KDE plots to the marginal axes

# %%
temp_df = covid_df[['Birth_Length', 'Gestational_Age_At_Birth']]
temp_df['Gestational_Age_At_Birth_Month'] = temp_df['Gestational_Age_At_Birth']/4.33

g = sns.JointGrid(data=temp_df, x='Birth_Length', y='Gestational_Age_At_Birth_Month')
g.plot(sns.scatterplot, sns.kdeplot)
# Out:
# /tmp/ipykernel_410795/2873972068.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['Gestational_Age_At_Birth_Month'] = temp_df['Gestational_Age_At_Birth']/4.33

# %% [markdown]
# 13. Find out each team's year-wise participation in FIFA. Given a dataset containing FIFA
# match details, create a heatmap using Seaborn to visualize the year-wise participation of
# each team. The dataset contains columns such as home_team, away_team, and Year.
# Combine the participation of both home and away teams, then group the data by Year
# and team. Finally, display the heatmap where the x-axis represents the year, the y-axis
# represents the team, and the color intensity reflects the number of participations.

# %%
home_team_df = fifa_matches_df[['home_team', 'Year']]
home_team_df = home_team_df.rename(columns = {'home_team': 'team'})
away_team_df = fifa_matches_df[['away_team', 'Year']]
away_team_df = away_team_df.rename(columns = {'away_team': 'team'})

temp_df = pd.concat([home_team_df, away_team_df])
temp_df['value'] = 1
grid = temp_df.pivot_table(index='team', columns='Year')

plt.figure(figsize=(12,12))
sns.heatmap(grid,linecolor='black',linewidths=0.5)
# Out:
# <Axes: xlabel='None-Year', ylabel='team'>
